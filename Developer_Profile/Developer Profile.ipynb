# %% [markdown]
# # Overview
#
# The questions we ask in our annual survey will help us improve the Stack Overflow community and the platform that serves them.
#
# This year, for example, we observed a significant evolution in the way developers educate themselves. For the rising cohort of coders under the age of 18, online resources like videos and blogs are more popular than books and school combined, a statistic that doesn’t hold for any of our other age cohorts. Overall, the profession is full of new joiners, with more than 50% indicating they have been coding for less than a decade, and more than 35% having less than five years in the trade.
#
# The challenge and opportunity for us is to continue expanding and improving our ability to help all developers and to make them feel welcome in our community.
#
# Read on for more great insights about the attitudes, tools, and environments that are shaping the art and practice of software today.

# %% [markdown]
# ## Developer Profile
#
# **What we know about the global community of developers**
#
# - Key territories
# - Experience
# - Developer roles
# - Education
# - Demographics

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000): 
        with pd.option_context("display.max_columns", 1000): 
            display(df)

# %%
# display_all(df.head())

# %%
# display_all(schema_df.head())

# %%
# df.shape

# %% [markdown]
# ## Key territories
#
# *Stack Overflow serves the international community, and our survey received responses from almost every country on Earth.*
#
#
# ### Geography
#
# The United States and India continue to provide the highest volume of survey responses, followed by Germany and UKI (UK and Ireland). The top ten countries account for almost 60% of all respondents. To see the top ten countries, refer to the methodology section. When we zoom into the United States (our top-responding country), we see that the states with established tech hubs have the most respondents: California, New York, Washington, and Texas.

# %% [markdown]
# ### Where do you live? *

# %%
# hide
responses_num = df['Country'].value_counts().head(10)
# responses_num.values

# %%
plt.rcParams['figure.dpi'] = 100
sns.set(style="whitegrid")

# Figure Size
fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(responses_num.index, responses_num.values)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)

# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 12, fontweight ='bold',
             color ='grey')

# Add plot title
ax.set_title('Top 10 Countries', fontsize = 14,
             loc ='left', )
 
# Add Text watermark
fig.text(0.9, 0.15, f'{responses_num.values.sum()} responses', fontsize = 12,
         color ='black', ha ='right', va ='bottom',
         alpha = 0.7)
 
# Show Plot
plt.show()

# %%
# hide
responses_all = df['Country'].value_counts()
# responses_all

# %%
# hide
responses_per_all = round(df['Country'].value_counts(normalize=True) * 100, ndigits=2)
# responses_per_all

# %%
responses_df = pd.concat([responses_all, responses_per_all], axis=1)

# %%
display_all(responses_df.set_axis(['Responses', 'Percentage'], axis='columns', inplace=False))
# Out:
#                                                     Responses  Percentage
# United States of America                                15288       18.32
# India                                                   10511       12.60
# Germany                                                  5625        6.74
# United Kingdom of Great Britain and Northern Ir...       4475        5.36
# Canada                                                   3012        3.61
# France                                                   2708        3.25
# Brazil                                                   2254        2.70
# Poland                                                   1805        2.16
# Netherlands                                              1772        2.12
# Italy                                                    1666        2.00
# Australia                                                1646        1.97
# Spain                                                    1485        1.78
# Russian Federation                                       1474        1.77
# Sweden                                                   1196        1.43
# China                                                    1055        1.26
# Turkey                                                   1054        1.26
# Switzerland                                               922        1.10
# Kosovo                                                     45        0.05
# United Republic of Tanzania                                43        0.05
# Iceland                                                    43        0.05
# Malta                                                      42        0.05
# Cameroon                                                   38        0.05
# Zimbabwe                                                   36        0.04
# Cambodia                                                   35        0.04
# Rwanda                                                     34        0.04
# Cuba                                                       34        0.04
# El Salvador                                                32        0.04
# Panama                                                     31        0.04
# Mauritius                                                  31        0.04
# Qatar                                                      29        0.03
# Kuwait                                                     29        0.03
# Bahrain                                                    28        0.03
# Senegal                                                    28        0.03
# Angola                                                     27        0.03
# Sudan                                                      27        0.03
# Palestine                                                  25        0.03
# Honduras                                                   24        0.03
# Zambia                                                     22        0.03
# Mongolia                                                   21        0.03
# Kyrgyzstan                                                 21        0.03
# Jamaica                                                    20        0.02
# Trinidad and Tobago                                        20        0.02
# Yemen                                                      20        0.02
# Oman                                                       20        0.02
# Nicaragua                                                  18        0.02
# Madagascar                                                 18        0.02
# Montenegro                                                 17        0.02
# Côte d'Ivoire                                              17        0.02
# Maldives                                                   16        0.02
# Benin                                                      15        0.02
# Turkmenistan                                               13        0.02
# Mozambique                                                 12        0.01
# Namibia                                                    12        0.01
# Andorra                                                    12        0.01
# Barbados                                                   12        0.01
# Congo, Republic of the...                                  12        0.01
# Libyan Arab Jamahiriya                                     11        0.01
# Malawi                                                     11        0.01
# Democratic Republic of the Congo                           10        0.01
# Swaziland                                                  10        0.01
# Tajikistan                                                  9        0.01
# Bahamas                                                     7        0.01
# Togo                                                        7        0.01
# Somalia                                                     7        0.01
# Guyana                                                      7        0.01
# Botswana                                                    6        0.01
# Cape Verde                                                  6        0.01
# North Korea                                                 6        0.01
# Haiti                                                       5        0.01
# Belize                                                      5        0.01
# Isle of Man                                                 5        0.01
# Mauritania                                                  5        0.01
# Bhutan                                                      5        0.01
# Suriname                                                    5        0.01
# Burundi                                                     5        0.01
# Fiji                                                        4        0.00
# Burkina Faso                                                4        0.00
# Lesotho                                                     4        0.00
# Lao People's Democratic Republic                            4        0.00
# Niger                                                       3        0.00
# Central African Republic                                    3        0.00
# Liberia                                                     3        0.00
# Saint Lucia                                                 3        0.00
# Djibouti                                                    3        0.00
# San Marino                                                  2        0.00
# Guinea                                                      2        0.00
# Sierra Leone                                                2        0.00
# Micronesia, Federated States of...                          2        0.00
# Chad                                                        2        0.00
# Gambia                                                      2        0.00
# Monaco                                                      2        0.00
# Mali                                                        2        0.00
# Brunei Darussalam                                           1        0.00
# Liechtenstein                                               1        0.00
# Saint Kitts and Nevis                                       1        0.00
# Dominica                                                    1        0.00
# Saint Vincent and the Grenadines                            1        0.00
# Tuvalu                                                      1        0.00
# Papua New Guinea                                            1        0.00
